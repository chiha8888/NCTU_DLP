# %% [markdown]
# # Lab2 DeepConvNet

# %%
import os
import torch
print(torch.__version__)
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader,TensorDataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from dataloader import read_bci_data
# Out:
# 1.4.0
# cuda

# %% [markdown]
# ## TensorDataset & DataLoader

# %%
X_train,y_train,X_test,y_test=read_bci_data()
dataset=TensorDataset(torch.from_numpy(X_train),torch.from_numpy(y_train))
loader_train=DataLoader(dataset,batch_size=64)
dataset=TensorDataset(torch.from_numpy(X_test),torch.from_numpy(y_test))
loader_test=DataLoader(dataset,batch_size=64)
print(f'test dataset:\n{dataset[:3]}')
# Out:
# (1080, 1, 2, 750) (1080,) (1080, 1, 2, 750) (1080,)
# test dataset:
# (tensor([[[[ -8.3359,  -8.7829,  -9.3748,  ...,  -2.1328,  -2.8224,  -2.0885],
#           [-10.6524,  -8.4476,  -5.9331,  ...,   0.5607,  -4.1266,  -8.1379]]],
#
#
#         [[[ -1.6904,  -3.2816,  -3.6523,  ...,   4.0093,   0.7018,   0.7155],
#           [  3.4033,   2.0698,  -1.6959,  ...,   7.7458,   3.5498,   3.7207]]],
#
#
#         [[[ -2.6835,  -0.4836,   1.9848,  ...,  -3.9513,   0.4729,   5.2923],
#           [  2.6602,   3.9587,   4.9871,  ...,  -0.6675,  -0.2266,   0.0633]]]],
#        dtype=torch.float64), tensor([1., 0., 1.], dtype=torch.float64))

# %%
randi=int(np.random.randint(0,X_train.shape[0],1))
print(f'sample_id:{randi}')
plt.figure(figsize=(10,2))
plt.plot(X_train[randi,0,0])
plt.figure(figsize=(10,2))
plt.plot(X_train[randi,0,1])
# Out:
# sample_id:593

# %% [markdown]
# ## Model
# ![deepConvNet](deepconvnet.png)

# %%
class DeepConvNet(nn.Module):
    def __init__(self,activation=nn.ELU()):
        super(DeepConvNet,self).__init__()
        self.conv0=nn.Conv2d(1,25,kernel_size=(1,5))
        channels=[25,25,50,100,200]
        kernel_sizes=[None,(2,1),(1,5),(1,5),(1,5)]
        for i in range(1,len(channels)):
            setattr(self,'conv'+str(i),nn.Sequential(
                nn.Conv2d(channels[i-1],channels[i],kernel_size=kernel_sizes[i]),
                nn.BatchNorm2d(channels[i],eps=1e-5,momentum=0.1),
                activation,
                nn.MaxPool2d(kernel_size=(1,2)),
                nn.Dropout(p=0.5)
            ))
        self.classify=nn.Linear(8600,2)
    def forward(self,X):
        out=self.conv0(X)
        out=self.conv1(out)
        out=self.conv2(out)
        out=self.conv3(out)
        out=self.conv4(out)
        out=out.view(out.shape[0],-1)
        neurons=out.shape[0]
        out=self.classify(out)
        return out

# %% [markdown]
# ## Train
# __loss function:__ cross entropy
# __optimizer:__ adam
# __learning rate:__ 0.001
# __epoch:__ 150
# __batch_size:__ 64
# __activation fuction:__ ReLU,LeakyReLU,ELU

# %%
Loss=nn.CrossEntropyLoss()
lr=0.001
epochs=300

# %%
def train_with_different_activation(loader_train,loader_test,activations,device):
    """
    Args:
        loader_train: training dataloader
        loader_test: testing dataloader
        activations: {ReLU,LeakyReLU,ELU} pytorch layer
        device: pytorch device gpu,cpu
    Return:
        dataframe: with column 'epoch','ReLU_train','ReLU_test','LeakyReLU_train'...
    """
    df=pd.DataFrame()
    df['epoch']=range(1,epochs+1)
    for name,activation in activations.items():
        """
        train model with an specific activation function
        """
        model=DeepConvNet(activation)
        model.to(device)
        optimizer=torch.optim.Adam(model.parameters(),lr=lr)
        acc_train=list()
        acc_test=list()
        for epoch in range(1,epochs+1):
            """
            train
            """
            model.train()
            loss=0
            correct=0
            for idx,(data,target) in enumerate(loader_train):
                data=data.to(device,dtype=torch.float)
                target=target.to(device,dtype=torch.long) #target type has to be 'long'
                predict=model(data)
                loss+=Loss(predict,target)
                correct+=predict.max(dim=1)[1].eq(target).cpu().sum()
                """
                update
                """
                optimizer.zero_grad()
                loss.backward(retain_graph=True)
                optimizer.step()
            loss/=len(loader_train.dataset)
            correct=100.*correct/len(loader_train.dataset)
            print(f'epcoh{epoch:>3d}  loss:{loss:.4f}  acc:{correct:.1f}%')
            acc_train.append(correct)
            """
            test
            """
            model.eval()
            correct=0
            for idx,(data,target) in enumerate(loader_test):
                data=data.to(device,dtype=torch.float)
                target=target.to(device,dtype=torch.long)
                predict=model(data)
                correct+=predict.max(dim=1)[1].eq(target).cpu().sum()
            correct=100.*correct/len(loader_test.dataset)
            acc_test.append(correct)
        df[name+'_train']=acc_train
        df[name+'_test']=acc_test
        torch.save(model.state_dict(),os.path.join('deepconvnet models',name+'.pt'))
    return df

# %%
activations={'ReLU':nn.ReLU(),'LeakyReLU':nn.LeakyReLU(),'ELU':nn.ELU()}
df=train_with_different_activation(loader_train,loader_test,activations,device)
# Out:
# epcoh  1  loss:0.0866  acc:49.4%
# epcoh  2  loss:0.2023  acc:51.1%
# epcoh  3  loss:0.3661  acc:50.0%
# epcoh  4  loss:0.1040  acc:51.7%
# epcoh  5  loss:0.2098  acc:50.9%
# epcoh  6  loss:0.1321  acc:51.9%
# epcoh  7  loss:0.0800  acc:51.6%
# epcoh  8  loss:0.2139  acc:50.0%
# epcoh  9  loss:0.0853  acc:53.1%
# epcoh 10  loss:0.0951  acc:50.3%
# epcoh 11  loss:0.1395  acc:50.4%
# epcoh 12  loss:0.0602  acc:53.9%
# epcoh 13  loss:0.0500  acc:51.1%
# epcoh 14  loss:0.1022  acc:50.1%
# epcoh 15  loss:0.0733  acc:52.3%
# epcoh 16  loss:0.0451  acc:50.2%
# epcoh 17  loss:0.0601  acc:52.2%
# epcoh 18  loss:0.0782  acc:50.2%
# epcoh 19  loss:0.0642  acc:51.6%
# epcoh 20  loss:0.0413  acc:54.6%
# epcoh 21  loss:0.0328  acc:50.8%
# epcoh 22  loss:0.0666  acc:52.2%
# epcoh 23  loss:0.0543  acc:55.1%
# epcoh 24  loss:0.0300  acc:56.2%
# epcoh 25  loss:0.0417  acc:53.1%
# epcoh 26  loss:0.0452  acc:51.9%
# epcoh 27  loss:0.0295  acc:57.4%
# epcoh 28  loss:0.0235  acc:61.6%
# epcoh 29  loss:0.0209  acc:58.2%
# epcoh 30  loss:0.0412  acc:54.8%
# epcoh 31  loss:0.0335  acc:58.7%
# epcoh 32  loss:0.0207  acc:63.1%
# epcoh 33  loss:0.0195  acc:63.5%
# epcoh 34  loss:0.0273  acc:55.4%
# epcoh 35  loss:0.0380  acc:61.9%
# epcoh102  loss:0.0075  acc:79.9%
# epcoh103  loss:0.0073  acc:79.7%
# epcoh104  loss:0.0066  acc:81.5%
# epcoh105  loss:0.0066  acc:82.2%
# epcoh106  loss:0.0068  acc:79.6%
# epcoh107  loss:0.0068  acc:80.1%
# epcoh108  loss:0.0072  acc:80.3%
# epcoh109  loss:0.0082  acc:77.0%
# epcoh110  loss:0.0093  acc:76.2%
# epcoh111  loss:0.0084  acc:76.5%
# epcoh112  loss:0.0083  acc:78.1%
# epcoh113  loss:0.0073  acc:78.4%
# epcoh114  loss:0.0078  acc:78.0%
# epcoh115  loss:0.0081  acc:79.3%
# epcoh116  loss:0.0077  acc:77.9%
# epcoh117  loss:0.0077  acc:79.0%
# epcoh118  loss:0.0061  acc:82.1%
# epcoh119  loss:0.0061  acc:82.7%
# epcoh120  loss:0.0058  acc:84.1%
# epcoh121  loss:0.0062  acc:82.5%
# epcoh122  loss:0.0065  acc:81.5%
# epcoh123  loss:0.0084  acc:77.4%
# epcoh124  loss:0.0119  acc:73.0%
# epcoh125  loss:0.0091  acc:76.5%
# epcoh126  loss:0.0079  acc:80.7%
# epcoh127  loss:0.0064  acc:81.5%
# epcoh128  loss:0.0070  acc:80.2%
# epcoh129  loss:0.0085  acc:78.5%
# epcoh130  loss:0.0074  acc:77.9%
# epcoh131  loss:0.0070  acc:81.9%
# epcoh132  loss:0.0061  acc:82.4%
# epcoh133  loss:0.0062  acc:82.8%
# epcoh134  loss:0.0072  acc:81.6%
# epcoh135  loss:0.0065  acc:82.2%
# epcoh136  loss:0.0066  acc:81.9%
# epcoh137  loss:0.0062  acc:82.3%
# epcoh138  loss:0.0058  acc:83.0%
# epcoh139  loss:0.0057  acc:84.2%
# epcoh140  loss:0.0060  acc:83.2%
# epcoh141  loss:0.0070  acc:81.2%
# epcoh142  loss:0.0082  acc:77.8%
# epcoh143  loss:0.0095  acc:76.1%
# epcoh144  loss:0.0077  acc:79.9%
# epcoh145  loss:0.0070  acc:82.3%
# epcoh146  loss:0.0063  acc:82.2%
# epcoh147  loss:0.0066  acc:80.8%
# epcoh148  loss:0.0069  acc:80.6%
# epcoh149  loss:0.0061  acc:83.1%
# epcoh150  loss:0.0058  acc:83.4%
# epcoh  1  loss:0.0945  acc:50.5%
# epcoh  2  loss:0.1758  acc:53.3%
# epcoh  3  loss:0.1498  acc:51.1%
# epcoh  4  loss:0.1911  acc:49.0%
# epcoh  5  loss:0.3218  acc:50.3%
# epcoh  6  loss:0.2030  acc:53.6%
# epcoh  7  loss:0.0650  acc:63.3%
# epcoh  8  loss:0.1522  acc:50.6%
# epcoh  9  loss:0.0894  acc:63.1%
# epcoh 10  loss:0.0472  acc:64.9%
# epcoh 11  loss:0.0538  acc:57.5%
# epcoh 12  loss:0.0703  acc:61.5%
# epcoh 13  loss:0.0343  acc:67.7%
# epcoh 14  loss:0.0310  acc:60.9%
# epcoh 15  loss:0.0492  acc:58.4%
# epcoh 16  loss:0.0683  acc:64.9%
# epcoh 17  loss:0.0278  acc:69.4%
# epcoh 18  loss:0.0313  acc:64.7%
# epcoh 19  loss:0.0293  acc:66.0%
# epcoh 86  loss:0.0079  acc:78.3%
# epcoh 87  loss:0.0077  acc:79.8%
# epcoh 88  loss:0.0073  acc:80.6%
# epcoh 89  loss:0.0072  acc:79.5%
# epcoh 90  loss:0.0074  acc:79.0%
# epcoh 91  loss:0.0077  acc:79.4%
# epcoh 92  loss:0.0083  acc:78.6%
# epcoh 93  loss:0.0130  acc:71.1%
# epcoh 94  loss:0.0214  acc:64.0%
# epcoh 95  loss:0.0130  acc:71.0%
# epcoh 96  loss:0.0091  acc:75.3%
# epcoh 97  loss:0.0094  acc:76.0%
# epcoh 98  loss:0.0084  acc:78.1%
# epcoh 99  loss:0.0085  acc:77.1%
# epcoh100  loss:0.0082  acc:79.4%
# epcoh101  loss:0.0084  acc:77.0%
# epcoh102  loss:0.0083  acc:78.3%
# epcoh103  loss:0.0070  acc:80.3%
# epcoh104  loss:0.0077  acc:78.7%
# epcoh105  loss:0.0089  acc:78.1%
# epcoh106  loss:0.0085  acc:77.6%
# epcoh107  loss:0.0075  acc:80.3%
# epcoh108  loss:0.0071  acc:81.4%
# epcoh109  loss:0.0070  acc:80.2%
# epcoh110  loss:0.0073  acc:80.4%
# epcoh111  loss:0.0067  acc:82.0%
# epcoh112  loss:0.0067  acc:81.9%
# epcoh113  loss:0.0069  acc:81.0%
# epcoh114  loss:0.0068  acc:81.9%
# epcoh115  loss:0.0068  acc:83.8%
# epcoh116  loss:0.0062  acc:83.3%
# epcoh117  loss:0.0062  acc:82.3%
# epcoh118  loss:0.0066  acc:82.1%
# epcoh119  loss:0.0074  acc:79.8%
# epcoh120  loss:0.0096  acc:78.0%
# epcoh121  loss:0.0103  acc:76.0%
# epcoh122  loss:0.0098  acc:76.0%
# epcoh123  loss:0.0071  acc:80.9%
# epcoh124  loss:0.0071  acc:80.5%
# epcoh125  loss:0.0077  acc:80.9%
# epcoh126  loss:0.0073  acc:78.8%
# epcoh127  loss:0.0080  acc:81.1%
# epcoh128  loss:0.0060  acc:83.9%
# epcoh129  loss:0.0062  acc:83.7%
# epcoh130  loss:0.0070  acc:81.7%
# epcoh131  loss:0.0062  acc:82.9%
# epcoh132  loss:0.0061  acc:83.8%
# epcoh133  loss:0.0058  acc:84.3%
# epcoh134  loss:0.0063  acc:83.6%
# epcoh135  loss:0.0062  acc:84.1%
# epcoh136  loss:0.0060  acc:84.0%
# epcoh137  loss:0.0060  acc:83.2%
# epcoh138  loss:0.0061  acc:83.8%
# epcoh139  loss:0.0061  acc:84.0%
# epcoh140  loss:0.0059  acc:84.4%
# epcoh141  loss:0.0062  acc:82.7%
# epcoh142  loss:0.0065  acc:82.2%
# epcoh143  loss:0.0073  acc:81.5%
# epcoh144  loss:0.0105  acc:77.6%
# epcoh145  loss:0.0109  acc:75.1%
# epcoh146  loss:0.0090  acc:79.7%
# epcoh147  loss:0.0057  acc:83.1%
# epcoh148  loss:0.0066  acc:82.2%
# epcoh149  loss:0.0068  acc:81.9%
# epcoh150  loss:0.0064  acc:83.5%
# epcoh  1  loss:0.1103  acc:50.8%
# epcoh  2  loss:0.1070  acc:58.7%
# epcoh  3  loss:0.2000  acc:55.5%
# epcoh 70  loss:0.0113  acc:78.2%
# epcoh 71  loss:0.0143  acc:71.2%
# epcoh 72  loss:0.0190  acc:72.4%
# epcoh 73  loss:0.0135  acc:77.5%
# epcoh 74  loss:0.0162  acc:70.3%
# epcoh 75  loss:0.0184  acc:73.2%
# epcoh 76  loss:0.0129  acc:75.4%
# epcoh 77  loss:0.0151  acc:71.5%
# epcoh 78  loss:0.0149  acc:75.3%
# epcoh 79  loss:0.0127  acc:76.8%
# epcoh 80  loss:0.0127  acc:75.1%
# epcoh 81  loss:0.0129  acc:74.3%
# epcoh 82  loss:0.0117  acc:76.8%
# epcoh 83  loss:0.0109  acc:77.7%
# epcoh 84  loss:0.0111  acc:76.3%
# epcoh 85  loss:0.0127  acc:74.7%
# epcoh 86  loss:0.0145  acc:75.1%
# epcoh 87  loss:0.0113  acc:76.2%
# epcoh 88  loss:0.0125  acc:72.8%
# epcoh 89  loss:0.0153  acc:74.1%
# epcoh 90  loss:0.0111  acc:77.2%
# epcoh 91  loss:0.0134  acc:70.3%
# epcoh 92  loss:0.0161  acc:73.6%
# epcoh 93  loss:0.0119  acc:77.8%
# epcoh 94  loss:0.0138  acc:70.6%
# epcoh 95  loss:0.0142  acc:76.0%
# epcoh 96  loss:0.0122  acc:77.8%
# epcoh 97  loss:0.0109  acc:76.4%
# epcoh 98  loss:0.0121  acc:76.7%
# epcoh 99  loss:0.0103  acc:79.0%
# epcoh100  loss:0.0096  acc:76.8%
# epcoh101  loss:0.0103  acc:78.9%
# epcoh102  loss:0.0096  acc:79.3%
# epcoh103  loss:0.0102  acc:77.7%
# epcoh104  loss:0.0111  acc:78.9%
# epcoh105  loss:0.0099  acc:79.8%
# epcoh106  loss:0.0088  acc:80.5%
# epcoh107  loss:0.0103  acc:78.6%
# epcoh108  loss:0.0087  acc:81.6%
# epcoh109  loss:0.0085  acc:78.1%
# epcoh110  loss:0.0095  acc:78.2%
# epcoh111  loss:0.0077  acc:82.6%
# epcoh112  loss:0.0093  acc:77.7%
# epcoh113  loss:0.0108  acc:76.9%
# epcoh114  loss:0.0095  acc:78.3%
# epcoh115  loss:0.0087  acc:80.9%
# epcoh116  loss:0.0092  acc:80.2%
# epcoh117  loss:0.0082  acc:80.2%
# epcoh118  loss:0.0105  acc:79.6%
# epcoh119  loss:0.0088  acc:81.1%
# epcoh120  loss:0.0086  acc:80.8%
# epcoh121  loss:0.0084  acc:81.4%
# epcoh122  loss:0.0093  acc:78.4%
# epcoh123  loss:0.0096  acc:79.4%
# epcoh124  loss:0.0094  acc:80.9%
# epcoh125  loss:0.0081  acc:81.9%
# epcoh126  loss:0.0089  acc:80.1%
# epcoh127  loss:0.0095  acc:81.1%
# epcoh128  loss:0.0070  acc:83.4%
# epcoh129  loss:0.0074  acc:83.1%
# epcoh130  loss:0.0091  acc:81.1%
# epcoh131  loss:0.0073  acc:83.2%
# epcoh132  loss:0.0083  acc:83.1%
# epcoh133  loss:0.0113  acc:80.5%
# epcoh134  loss:0.0094  acc:80.8%
# epcoh135  loss:0.0078  acc:82.7%
# epcoh136  loss:0.0066  acc:84.4%
# epcoh137  loss:0.0080  acc:82.2%
# epcoh138  loss:0.0080  acc:84.6%
# epcoh139  loss:0.0071  acc:83.5%
# epcoh140  loss:0.0074  acc:83.5%
# epcoh141  loss:0.0087  acc:82.1%
# epcoh142  loss:0.0079  acc:84.0%
# epcoh143  loss:0.0083  acc:82.6%
# epcoh144  loss:0.0071  acc:85.5%
# epcoh145  loss:0.0070  acc:84.4%
# epcoh146  loss:0.0069  acc:85.9%
# epcoh147  loss:0.0068  acc:84.9%
# epcoh148  loss:0.0078  acc:83.7%
# epcoh149  loss:0.0085  acc:82.4%
# epcoh150  loss:0.0066  acc:84.4%

# %% [markdown]
# ## Plot

# %%
df
# Out:
#      epoch       ReLU_train        ReLU_test  LeakyReLU_train  \
# 0        1  tensor(49.3519)      tensor(50.)  tensor(50.4630)
# 1        2  tensor(51.1111)      tensor(50.)  tensor(53.3333)
# 2        3      tensor(50.)      tensor(50.)  tensor(51.1111)
# 3        4  tensor(51.6667)  tensor(49.8148)  tensor(48.9815)
# 4        5  tensor(50.9259)  tensor(51.2037)  tensor(50.2778)
# 5        6  tensor(51.9444)      tensor(50.)  tensor(53.6111)
# 6        7  tensor(51.5741)  tensor(50.3704)  tensor(63.3333)
# 7        8      tensor(50.)  tensor(50.3704)  tensor(50.5556)
# 8        9  tensor(53.1481)      tensor(50.)  tensor(63.1481)
# 9       10  tensor(50.2778)  tensor(50.1852)  tensor(64.9074)
# 10      11  tensor(50.3704)  tensor(49.5370)  tensor(57.5000)
# 11      12  tensor(53.8889)  tensor(50.3704)  tensor(61.4815)
# 12      13  tensor(51.1111)      tensor(50.)  tensor(67.6852)
# 13      14  tensor(50.0926)  tensor(52.8704)  tensor(60.9259)
# 14      15  tensor(52.3148)  tensor(50.0926)  tensor(58.4259)
# 15      16  tensor(50.1852)  tensor(50.8333)  tensor(64.9074)
# 16      17  tensor(52.2222)  tensor(54.8148)  tensor(69.3519)
# 17      18  tensor(50.1852)  tensor(54.8148)  tensor(64.7222)
# 18      19  tensor(51.5741)  tensor(52.9630)  tensor(66.0185)
# 19      20  tensor(54.6296)  tensor(50.4630)  tensor(70.1852)
# 20      21  tensor(50.8333)  tensor(52.4074)  tensor(68.4259)
# 21      22  tensor(52.2222)  tensor(58.5185)  tensor(68.2407)
# 22      23  tensor(55.0926)  tensor(52.5000)  tensor(65.7407)
# 23      24  tensor(56.2037)  tensor(54.2593)  tensor(69.0741)
# 24      25  tensor(53.1481)  tensor(53.4259)  tensor(72.5000)
# 25      26  tensor(51.8519)  tensor(54.6296)  tensor(71.0185)
# 26      27  tensor(57.4074)  tensor(59.1667)  tensor(70.8333)
# 27      28  tensor(61.5741)  tensor(54.4444)  tensor(66.4815)
# 28      29  tensor(58.2407)  tensor(56.4815)  tensor(65.3704)
# 29      30  tensor(54.8148)  tensor(61.5741)  tensor(69.9074)
# ..     ...              ...              ...              ...
# 120    121  tensor(82.5000)  tensor(72.5000)  tensor(76.0185)
# 121    122  tensor(81.4815)  tensor(73.1481)  tensor(76.0185)
# 122    123  tensor(77.4074)  tensor(73.0556)  tensor(80.9259)
# 18   tensor(66.6667)  tensor(70.9259)  tensor(61.0185)
# 19   tensor(66.7593)  tensor(61.9444)  tensor(68.8889)
# 20   tensor(65.3704)  tensor(68.0556)  tensor(67.5926)
# 21   tensor(70.6481)  tensor(70.4630)  tensor(65.4630)
# 22   tensor(69.0741)  tensor(63.7963)  tensor(70.2778)
# 23   tensor(67.8704)  tensor(70.6481)  tensor(68.0556)
# 24   tensor(68.2407)  tensor(71.9444)      tensor(65.)
# 25   tensor(64.6296)  tensor(61.4815)  tensor(68.7963)
# 26   tensor(69.2593)  tensor(70.4630)  tensor(66.4815)
# 27   tensor(70.1852)  tensor(71.9444)      tensor(70.)
# 28   tensor(66.7593)  tensor(71.0185)  tensor(65.6481)
# 29   tensor(65.6481)  tensor(68.7037)      tensor(70.)
# ..               ...              ...              ...
# 120  tensor(73.1481)  tensor(81.3889)  tensor(71.7593)
# 121  tensor(70.8333)  tensor(78.4259)  tensor(70.3704)
# 122  tensor(72.7778)  tensor(79.3519)  tensor(72.7778)
# 123  tensor(71.4815)  tensor(80.9259)  tensor(71.6667)
# 124  tensor(73.1481)  tensor(81.8519)  tensor(70.4630)
# 125  tensor(73.3333)  tensor(80.0926)  tensor(71.5741)
# 126  tensor(70.3704)  tensor(81.1111)  tensor(72.8704)
# 127  tensor(74.6296)  tensor(83.4259)  tensor(72.9630)
# 128  tensor(73.6111)  tensor(83.1481)  tensor(72.5000)
# 129  tensor(70.3704)  tensor(81.1111)  tensor(72.5000)
# 130  tensor(72.7778)  tensor(83.2407)  tensor(74.4444)
# 131  tensor(72.6852)  tensor(83.0556)  tensor(72.5000)
# 132  tensor(72.9630)  tensor(80.4630)  tensor(70.4630)
# 133  tensor(71.2963)  tensor(80.8333)  tensor(73.1481)
# 134  tensor(73.5185)  tensor(82.6852)  tensor(71.9444)
# 135  tensor(72.5000)  tensor(84.3519)  tensor(72.3148)
# 136  tensor(73.7037)  tensor(82.2222)  tensor(72.8704)
# 137  tensor(71.1111)  tensor(84.6296)  tensor(72.6852)
# 138  tensor(71.0185)  tensor(83.5185)  tensor(73.0556)
# 139  tensor(73.0556)  tensor(83.5185)  tensor(73.7963)
# 140  tensor(73.7037)  tensor(82.1296)  tensor(72.3148)
# 141  tensor(73.7037)  tensor(83.9815)  tensor(71.0185)
# 142  tensor(72.2222)  tensor(82.5926)  tensor(72.0370)
# 143  tensor(72.5926)  tensor(85.4630)  tensor(73.3333)
# 144  tensor(73.0556)  tensor(84.4444)  tensor(73.6111)
# 145  tensor(69.6296)  tensor(85.9259)  tensor(72.5000)
# 146  tensor(73.6111)  tensor(84.9074)  tensor(71.3889)
# 147  tensor(72.9630)  tensor(83.7037)  tensor(73.9815)
# 148  tensor(72.8704)  tensor(82.4074)  tensor(72.4074)
# 149      tensor(75.)  tensor(84.3519)  tensor(70.2778)
#
# [150 rows x 7 columns]

# %%
def plot(dataframe):
    fig=plt.figure(figsize=(10,6))
    for name in dataframe.columns[1:]:
        plt.plot('epoch',name,data=dataframe)
    plt.legend()
    plt.title('DeepConvNet')
    return fig

# %%
figure=plot(df)
figure.savefig('deepconvnet result.png')
